# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pandas as pd
import numpy as np

mpl.rcParams['figure.dpi'] = 150

sns.set_style("whitegrid")

# %%
smex = pd.read_csv('./smex.csv')
smex.head()
# Out:
#    N_pix  T_mag    noise  noise_star     noise_sky      noise_ro  noise_sys
# 0     35   4.00  0.00005    0.000002  1.621000e-08  1.326000e-08    0.00005
# 1     35   4.05  0.00005    0.000002  1.697000e-08  1.389000e-08    0.00005
# 2     35   4.10  0.00005    0.000002  1.777000e-08  1.454000e-08    0.00005
# 3     35   4.15  0.00005    0.000002  1.861000e-08  1.523000e-08    0.00005
# 4     35   4.20  0.00005    0.000003  1.948000e-08  1.595000e-08    0.00005

# %%
tess = pd.read_csv('./tess.csv')
tess.head()
# Out:
#    N_pix  T_mag     noise  noise_star     noise_sky      noise_ro  noise_sys
# 0     35   4.00  0.000061    0.000009  2.269000e-07  2.122000e-07    0.00006
# 1     35   4.05  0.000061    0.000009  2.376000e-07  2.222000e-07    0.00006
# 2     35   4.10  0.000061    0.000010  2.488000e-07  2.327000e-07    0.00006
# 3     35   4.15  0.000061    0.000010  2.605000e-07  2.436000e-07    0.00006
# 4     35   4.20  0.000061    0.000010  2.728000e-07  2.551000e-07    0.00006

# %%
plt.plot(smex['T_mag'], 1e6*smex['noise_star'], label='Poisson')
plt.plot(smex['T_mag'], 1e6*smex['noise_sky'], label='sky')
plt.plot(smex['T_mag'], 1e6*smex['noise_ro'], label='readout')
plt.plot(smex['T_mag'], 1e6*smex['noise_sys'], label='systematic')
plt.plot(smex['T_mag'], 1e6*smex['noise'], 'k', label='SMEX total', lw=2)
plt.legend()
plt.xlim(4,16)
plt.semilogy()
plt.xlabel(r"T [mag]")
plt.ylabel(r"$\sigma$ [ppm hr$^{1/2}$]")
plt.show()




#plt.plot(smex['T_mag'], 1e6*smex['noise_star'], label='Poisson')
#plt.plot(smex['T_mag'], 1e6*smex['noise_sky'], label='sky')
#plt.plot(smex['T_mag'], 1e6*smex['noise_ro'], label='readout')
#plt.plot(smex['T_mag'], 1e6*smex['noise_sys'], label='systematic')
plt.plot(smex['T_mag'], 1e6*smex['noise'], 'k', label='SMEX total', lw=2)
plt.plot(tess['T_mag'], 1e6*tess['noise'], 'k--', label='TESS total', lw=2)
plt.legend()
plt.xlim(4,16)
plt.semilogy()
plt.xlabel(r"T [mag]")
plt.ylabel(r"$\sigma$ [ppm hr$^{1/2}$]")
#plt.plot(kep['kepmag'], kep['rrmscdpp03p0'], ',', alpha=0.1, color='k')
plt.plot(tmp['kepmag'], tmp['rrmscdpp01p5'], ',', alpha=0.1, color='k')

plt.show()

# %%
kep = pd.read_parquet('for_lb.parquet')
kep.head()
# Out:
#     kepid  kepmag  phot_g_mean_mag  phot_rp_mean_mag  phot_bp_mean_mag  \
# 0  757076  11.678        11.607049         10.965837         12.116295
# 1  757099  13.152        13.095681         12.477260         13.552989
# 2  757137   9.196         9.125692          8.415903          9.734418
# 3  757280  11.901        11.775861         11.345596         12.062609
# 4  757450  15.264        15.178850         14.519423         15.693465
#
#    rrmscdpp03p0
# 0       112.149
# 1       694.580
# 2        68.520
# 3        52.567
# 4       346.195

# %%
df = pd.read_csv('Kepler-Q1-Q17-DR25-CDPP3.csv')
df.head()
# Out:
#       kepid  rrmscdpp03p0
# 0  10000785       445.410
# 1  10000797        80.767
# 2  10000800       226.348
# 3  10000823       181.468
# 4  10000827       124.834

# %%
from astropy.io import ascii

# %%
tmp = ascii.read("/Users/tdavid/Dropbox (Simons Foundation)/multis/data/Kepler-Q1-Q17-DR25-KOI.txt")

# %%
tmp.info()
# Out:
# <Table length=200038>
#       name       dtype    unit     class     n_bad
# --------------- ------- ------- ------------ ------
#           kepid   int64               Column      0
#  tm_designation   str25         MaskedColumn    569
#            teff   int64       K       Column      0
#       teff_err1   int64       K MaskedColumn   3186
#       teff_err2   int64       K MaskedColumn   3449
#            logg float64 cm / s2       Column      0
#       logg_err1 float64 cm / s2 MaskedColumn   3186
#       logg_err2 float64 cm / s2 MaskedColumn   3186
#             feh float64     dex       Column      0
#        feh_err1 float64     dex MaskedColumn   3186
#        feh_err2 float64     dex MaskedColumn   3186
#            mass float64   solar MaskedColumn   2942
#       mass_err1 float64   solar MaskedColumn   3190
#       mass_err2 float64   solar MaskedColumn   3187
#          radius float64   solar       Column      0
#     radius_err1 float64   solar MaskedColumn   3186
# ...
